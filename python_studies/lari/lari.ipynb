# %%
import pandas as pd
import matplotlib.pyplot as plt

def ler_arquivo(nome):
    df =  pd.read_csv(nome)
    return df

def grafico_barras(barra, indice, ano):
    pass

# programa principal
d = ler_arquivo("desc.csv")
print(d)

idhm_1991 = d[d["ano"] == 1991]
print(idhm_1991[["sigla", "idhm"]])

idhm_2000 = d[d["ano"] == 2000]
print(idhm_2000[["sigla", "idhm"]])

idhm_2010 = d[d["ano"] == 2010]
print(idhm_2010[["sigla", "idhm"]])

idhm_estado = d[["sigla", "idhm"]].groupby("sigla").mean()
print(idhm_estado)
idhm_estado.plot()
plt.show()

idhm_estado_ordem = d[["sigla", "idhm"]].groupby("sigla").mean()
print(idhm_estado_ordem.sort_values("idhm"))
idhm_estado_ordem.plot()
plt.show()

'''
while True:
    n_habitantes = int(input("Informe o número mínimo de habitantes: "))
    idhm_l_d = {}
    idhm_r_d = {}
    idhm_d = {}
'''
# Out:
#            SIGLA                                       nome curto  \
# 0             uf                   Código da Unidade da Federação
# 1            ufn                     Nome da Unidade da Federação
# 2        codmun6                              Código do Município
# 3        codmun7                              Código do Município
# 4        nomemun                                Nome do Município
# ..           ...                                              ...
# 232  i_freq_prop  Subíndice de frequência escolar - IDHM Educação
# 233         idhm                                             IDHM
# 234       idhm_e                                    IDHM Educação
# 235       idhm_l                                 IDHM Longevidade
# 236       idhm_r                                       IDHM Renda
#
#                                             nome longo  \
# 0                       Código da Unidade da Federação
# 1                         Nome da Unidade da Federação
# ...
