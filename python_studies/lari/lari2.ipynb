# %%
import pandas as pd
import matplotlib.pyplot as plt

def ler_arquivo(nome):
    df =  pd.read_csv(nome)
    return df

def grafico_barras(df, indice, ano):
    df = df[df['ano'] == ano]
    df = df.sort_values(by=indice)
    s = pd.Series(df[indice].head(20).to_list(), index=df['município'].head(20))
    s.plot.barh()

def grafico_linhas(df, estado):
    df = df[df['uf'] == estado]
    dados = df.loc[:, ('idhm', 'idhm_e', 'idhm_r', 'idhm_l')]
    anos = df.

# programa principal
d = ler_arquivo("atlas.csv")
#print(d)
#grafico_barras(d, 'idhm', 2010)
grafico_linhas(d, 11)
"""
anos = (1991, 2000, 2010)
idhm_ano = {}
for ano in anos:
    idhm_ano[ano] = d[d["ano"] == ano]

idhm_estado = d[["sigla", "idhm"]].groupby("sigla").mean()
print(idhm_estado)
idhm_estado.plot()
plt.show()

idhm_estado_ordem = d[["sigla", "idhm"]].groupby("sigla").mean()
print(idhm_estado_ordem.sort_values("idhm"))
idhm_estado_ordem.plot()
plt.show()

idhm_ano[1991]
d.head().loc[:, ('ano', 'idhm', 'idhm_l', 'idhm_r', 'idhm_e')]
"""
# Out:
# '\nanos = (1991, 2000, 2010)\nidhm_ano = {}\nfor ano in anos:\n    idhm_ano[ano] = d[d["ano"] == ano]\n\nidhm_estado = d[["sigla", "idhm"]].groupby("sigla").mean()\nprint(idhm_estado)\nidhm_estado.plot()\nplt.show()\n\nidhm_estado_ordem = d[["sigla", "idhm"]].groupby("sigla").mean()\nprint(idhm_estado_ordem.sort_values("idhm"))\nidhm_estado_ordem.plot()\nplt.show()\n\nidhm_ano[1991]\nd.head().loc[:, (\'ano\', \'idhm\', \'idhm_l\', \'idhm_r\', \'idhm_e\')]\n'
