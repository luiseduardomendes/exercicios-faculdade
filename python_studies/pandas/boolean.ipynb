# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('nba-stats/Players.csv', index_col=0)
df.columns
# Out:
# Index(['Player', 'height', 'weight', 'collage', 'born', 'birth_city',
#        'birth_state'],
#       dtype='object')

# %%
born_in_California = df[df['birth_state'] == 'California']
born_in_California
# Out:
#                Player  height  weight  \
# 22       Bill Calhoun   190.0    81.0
# 50        Bob Feerick   190.0    86.0
# 74       Alex Hannum*   201.0    95.0
# 117       John Mandic   193.0    92.0
# 130   Vern Mikkelsen*   201.0   104.0
# ...               ...     ...     ...
# 3845  Marquese Chriss   208.0   105.0
# 3861  Jonathan Gibson   188.0    83.0
# 3890      David Nwaba   193.0    94.0
# 3894      Gary Payton   193.0    81.0
# 3908    Isaiah Taylor   190.0    77.0
#
#                                                 collage    born  \
# 22                        City College of San Francisco  1927.0
# 50                               Santa Clara University  1920.0
# 74                    University of Southern California  1923.0
# 117                             Oregon State University  1919.0
# 130                                  Hamline University  1928.0
# ...                                                 ...     ...
# ...

# %%
mean = df['height'].mean()

above_mean = df[df['height'] > mean].sort_values(by='height').reset_index()
below_mean = df[df['height'] < mean].sort_values(by='height').reset_index()
