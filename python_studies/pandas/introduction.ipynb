# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Tarefa
# 1. height and weight mean of NBA players

# %%
df = pd.read_csv('nba-stats/Players.csv')

weight_mean = df['weight'].mean()
height_mean = df['height'].mean()
weight_mean, height_mean
df
# Out:
#       Unnamed: 0             Player  height  weight  \
# 0              0    Curly Armstrong   180.0    77.0
# 1              1       Cliff Barker   188.0    83.0
# 2              2      Leo Barnhorst   193.0    86.0
# 3              3         Ed Bartels   196.0    88.0
# 4              4        Ralph Beard   178.0    79.0
# ...          ...                ...     ...     ...
# 3917        3917      Troy Williams   198.0    97.0
# 3918        3918       Kyle Wiltjer   208.0   108.0
# 3919        3919  Stephen Zimmerman   213.0   108.0
# 3920        3920        Paul Zipser   203.0    97.0
# 3921        3921        Ivica Zubac   216.0   120.0
#
#                               collage    born      birth_city  \
# 0                  Indiana University  1918.0             NaN
# 1              University of Kentucky  1921.0        Yorktown
# 2            University of Notre Dame  1924.0             NaN
# 3     North Carolina State University  1925.0             NaN
# ...

# %% [markdown]
# 2. make a column with the ratio weight/height

# %%
df['weight_height'] = df['weight']/df['height']
df
# Out:
#       Unnamed: 0             Player  height  weight  \
# 0              0    Curly Armstrong   180.0    77.0
# 1              1       Cliff Barker   188.0    83.0
# 2              2      Leo Barnhorst   193.0    86.0
# 3              3         Ed Bartels   196.0    88.0
# 4              4        Ralph Beard   178.0    79.0
# ...          ...                ...     ...     ...
# 3917        3917      Troy Williams   198.0    97.0
# 3918        3918       Kyle Wiltjer   208.0   108.0
# 3919        3919  Stephen Zimmerman   213.0   108.0
# 3920        3920        Paul Zipser   203.0    97.0
# 3921        3921        Ivica Zubac   216.0   120.0
#
#                               collage    born      birth_city  \
# 0                  Indiana University  1918.0             NaN
# 1              University of Kentucky  1921.0        Yorktown
# 2            University of Notre Dame  1924.0             NaN
# 3     North Carolina State University  1925.0             NaN
# ...

# %% [markdown]
# 3. which is the max height, max weight, min height and min weight

# %%
max_height = df['height'].max()
min_height = df['height'].min()
max_weight = df['weight'].max()
min_weight = df['weight'].min()
min_height, min_weight, max_height, max_weight
# Out:
# (160.0, 60.0, 231.0, 163.0)

# %% [markdown]
# 4. estado de onde sai mais jogadores

# %%
states = [state for state in df['birth_state'] if state != 'NaN' and type(state) == str]
states = pd.Series(list(set(states)))

players_by_state = pd.Series(np.zeros(len(states)))

for i, state in enumerate(df['birth_state']):
    if state != 'NaN' and type(state) == str:
        index = list(states).index(state)
        players_by_state[index] += 1

df2 = pd.DataFrame(
    {
        'states': states,
        'num_players': players_by_state
    }
)

i = df2['num_players'].idxmax()
df2['states'][i]
# Out:
# 'California'

# %% [markdown]
# 5. which is the tallest player

# %%
i = df['height'].idxmax()
tallest_player = df['Player'][i]
height = df['height'][i]

tallest_player, height
# Out:
# ('Manute Bol', 231.0)
